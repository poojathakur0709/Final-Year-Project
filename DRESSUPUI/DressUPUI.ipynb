# %%
import sys
from PyQt5 import QtCore, QtGui, QtWidgets
import time
from threading import *
from PyQt5.QtCore import *
from PyQt5.QtGui import *
from PyQt5.QtWidgets import *
import import_ipynb
import GlobalVar
from createDatabase import *
app = QtWidgets.QApplication(sys.argv)
MainWindow = QtWidgets.QMainWindow()
from AllFunction import *
from matplotlib import colors
import matplotlib.pyplot as plt
#####################
import tensorflow as tf
from tensorflow import keras
# Out:
# importing Jupyter notebook from GlobalVar.ipynb
# importing Jupyter notebook from createDatabase.ipynb
# importing Jupyter notebook from AllFunction.ipynb
# ['Basic', 'Analogous']
# ['Basic']
# None
# ['Basic', 'Winter']
# ['Basic', 'Analogous', 'Winter']
# None
# ['Basic', 'Analogous', 'Winter']
# None
# ['Basic', 'Neutral']
# ['Analogous']

# %%
class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        self.thread()#load models thred faster 
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(960, 540)
        MainWindow.setMinimumSize(QtCore.QSize(960, 540))
        MainWindow.setMaximumSize(QtCore.QSize(960, 540))
        MainWindow.setCursor(QtGui.QCursor(QtCore.Qt.BlankCursor))
        MainWindow.setStyleSheet("background-color: #420516;")
        MainWindow.setTabShape(QtWidgets.QTabWidget.Rounded)
        
        
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setCursor(QtGui.QCursor(QtCore.Qt.OpenHandCursor))
        self.centralwidget.setObjectName("centralwidget")
        self.NavLine = QtWidgets.QFrame(self.centralwidget)
        self.NavLine.setGeometry(QtCore.QRect(0, 40, 960, 2))
        self.NavLine.setAutoFillBackground(False)
        self.NavLine.setStyleSheet("color:white;")
        self.NavLine.setFrameShadow(QtWidgets.QFrame.Plain)
        self.NavLine.setLineWidth(0)
        self.NavLine.setMidLineWidth(0)
        self.NavLine.setFrameShape(QtWidgets.QFrame.HLine)
        self.NavLine.setObjectName("NavLine")
        self.ProjectNameLabel = QtWidgets.QLabel(self.centralwidget)
        self.ProjectNameLabel.setGeometry(QtCore.QRect(43, 6, 150, 25))
        self.ProjectNameLabel.setStyleSheet("font-family: Segoe Script;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 20px;\n"
"line-height: 25px;\n"
"\n"
"color: #FFFFFF;\n"
"")
        self.ProjectNameLabel.setObjectName("ProjectNameLabel")
        self.IconMain = QtWidgets.QLabel(self.centralwidget)
        self.IconMain.setGeometry(QtCore.QRect(10, 6, 20, 25))
        self.IconMain.setPixmap(QtGui.QPixmap("logos/hanger.png").scaled(20,20))
        self.IconMain.setObjectName("IconMain")
        self.IconMain.setStyleSheet("")
        
        self.IconMainCut = QtWidgets.QPushButton(self.centralwidget)
        self.IconMainCut.setGeometry(QtCore.QRect(930, 6, 20, 25))
        icon20 = QtGui.QIcon()
        icon20.addPixmap(QtGui.QPixmap("logos/qut.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.IconMainCut.setIcon(icon20)
        #self.IconMainCut.setPixmap(QtGui.QPixmap("logos/qut.png").scaled(20,20))
        self.IconMainCut.setObjectName("IconMain")
        self.IconMainCut.setStyleSheet("")
        #self.IconMainCut.clicked.connect(self.Exit)
        
        self.MainTabs = QtWidgets.QTabWidget(self.centralwidget)
        self.MainTabs.setGeometry(QtCore.QRect(0, 40, 960, 500))
        font = QtGui.QFont()
        font.setStyleStrategy(QtGui.QFont.PreferDefault)
        self.MainTabs.setFont(font)
        self.MainTabs.setMouseTracking(False)
        self.MainTabs.setFocusPolicy(QtCore.Qt.NoFocus)
        self.MainTabs.setContextMenuPolicy(QtCore.Qt.NoContextMenu)
        self.MainTabs.setLayoutDirection(QtCore.Qt.LeftToRight)
        self.MainTabs.setAutoFillBackground(False)
        self.MainTabs.setTabPosition(QtWidgets.QTabWidget.East)
        self.MainTabs.setTabShape(QtWidgets.QTabWidget.Rounded)
        self.MainTabs.setIconSize(QtCore.QSize(66, 100))
        self.MainTabs.setElideMode(QtCore.Qt.ElideNone)
        self.MainTabs.setMovable(False)
        self.MainTabs.setTabBarAutoHide(False)
        self.MainTabs.setObjectName("MainTabs")
        

        self.IconMain = QtWidgets.QLabel(self.MainTabs)
        self.IconMain.setGeometry(QtCore.QRect(200, 10, 200, 100))
        #icon15 = QtGui.QIcon()
        self.IconMain.setPixmap(QtGui.QPixmap("logos/hanger.png").scaled(100,100))
        #self.IconMain.setIcon(icon15)
        #self.IconMain.setIconSize(QtCore.QSize(88, 100))
        self.IconMain.setObjectName("IconMain")
        self.IconMain.setStyleSheet("")

        self.Heading = QtWidgets.QLabel(self.MainTabs)
        self.Heading.setGeometry(QtCore.QRect(350, 40,431, 71))
        font = QtGui.QFont()
        font.setFamily("Segoe Script")
        font.setPointSize(36)
        font.setBold(True)
        font.setWeight(75)
        self.Heading.setFont(font)
        self.Heading.setStyleSheet("color:white;")
        self.Heading.setObjectName("Heading")
        self.SignupMainBT = QtWidgets.QPushButton(self.MainTabs)
        self.SignupMainBT.setGeometry(QtCore.QRect(490, 400, 400, 50)) #30, 340, 400, 50
        self.SignupMainBT.setStyleSheet("\n"
"background: #C4C4C4;\n"
"border-radius: 10px;\n"
"font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 24px;\n"
"line-height: 90%;")
        self.SignupMainBT.setObjectName("SignupMainBT")
        self.SignupMainBT.clicked.connect(self.Signup)
        self.LoginMainBT = QtWidgets.QPushButton(self.MainTabs)
        self.LoginMainBT.setGeometry(QtCore.QRect(60, 400, 400, 50))
        self.LoginMainBT.setStyleSheet("\n"
"background: #C4C4C4;\n"
"border-radius: 10px;\n"
"font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 24px;\n"
"line-height: 90%;")
        self.LoginMainBT.setObjectName("LoginMainBT")
        
        
        self.LoginMainBT.clicked.connect(self.LoginMainBT_clicked)
        
        self.Content = QtWidgets.QLabel(self.MainTabs)
        self.Content.setGeometry(QtCore.QRect(270, 140, 400,40))
        font = QtGui.QFont()
        font.setFamily("Segoe Script")
        font.setPointSize(12)
        self.Content.setFont(font)
        self.Content.setStyleSheet("color:white;")
        self.Content.setObjectName("Content")
        
        
        self.Content1 = QtWidgets.QLabel(self.MainTabs)
        self.Content1.setGeometry(QtCore.QRect(360, 190, 400,80))
        font = QtGui.QFont()
        font.setFamily("Segoe Script")
        font.setPointSize(12)
        self.Content1.setFont(font)
        self.Content1.setStyleSheet("color:white;")
        self.Content1.setObjectName("Content")
        
        self.Content2 = QtWidgets.QLabel(self.MainTabs)
        self.Content2.setGeometry(QtCore.QRect(270, 280, 400,50))
        font = QtGui.QFont()
        font.setFamily("Segoe Script")
        font.setPointSize(12)
        self.Content2.setFont(font)
        self.Content2.setStyleSheet("color:white;")
        self.Content2.setObjectName("Content")
       
        
        icon16 = QtGui.QIcon()
        icon16.addPixmap(QtGui.QPixmap(":/newPrefix/logos/MapsTab.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        
        MainWindow.setCentralWidget(self.centralwidget)

        self.retranslateUi(MainWindow)
        self.MainTabs.setCurrentIndex(0)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)
        MainWindow.setTabOrder(self.IconMain, self.SignupMainBT)
        MainWindow.setTabOrder(self.SignupMainBT, self.LoginMainBT)
    def LoginMainBT_clicked(self):
        self.Window=QtWidgets.QMainWindow()
        self.ui=Ui_MainWindowLogin()
        self.ui.setupUi(self.Window)
        self.Window.show()
        #QCoreApplication.instance().quit
        #MainWindow.close()
    def Signup(self):
        self.Window=QtWidgets.QMainWindow()
        self.ui=Ui_MainWindowSignup()
        self.ui.setupUi(self.Window)
        self.Window.show()
        #self.hide()
        #MainWindow.close()
    def load_model(self):

        GlobalVar.sub_model = tf.keras.models.load_model('models/model_sub')
        GlobalVar.top_model = tf.keras.models.load_model('models/model_top')
        GlobalVar.bottom_model = tf.keras.models.load_model('models/model_bottom')
        GlobalVar.foot_model = tf.keras.models.load_model('models/model_shoes')
        print("loadModel")
    def thread(self):
        t1=Thread(target=self.load_model)
        t1.start()

    def Exit(self):
        print("clicked")
        #slef.pfdgfdhg.hide()
        

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "MainWindow"))
        self.ProjectNameLabel.setText(_translate("MainWindow", "Dress UP"))
        #self.IconMain.setText(_translate("MainWindow", "PushButton"))
        self.Heading.setText(_translate("MainWindow", "Dress UP"))
        self.SignupMainBT.setText(_translate("MainWindow", "SIGNUP"))
        self.LoginMainBT.setText(_translate("MainWindow", "Login"))
        self.Content.setText(_translate("MainWindow", '''<h3>No Matter how you feel '''))
        self.Content1.setText(_translate("MainWindow", '''<h3>Get UP <br>Dress UP  '''))
        self.Content2.setText(_translate("MainWindow", '''<h3>Show up and Never give up '''))

#import source_rc  <h1>Get UP </h1>dress up  show up and never give up

# %%
class Ui_MainWindowLogin(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(960, 540)
        MainWindow.setMinimumSize(QtCore.QSize(960, 540))
        MainWindow.setMaximumSize(QtCore.QSize(960, 540))
        MainWindow.setCursor(QtGui.QCursor(QtCore.Qt.BlankCursor))
        MainWindow.setStyleSheet("background-color: #420516;")
        MainWindow.setTabShape(QtWidgets.QTabWidget.Rounded)
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setCursor(QtGui.QCursor(QtCore.Qt.OpenHandCursor))
        self.centralwidget.setObjectName("centralwidget")
        self.NavLine = QtWidgets.QFrame(self.centralwidget)
        self.NavLine.setGeometry(QtCore.QRect(0, 40, 960, 2))
        self.NavLine.setAutoFillBackground(False)
        self.NavLine.setStyleSheet("color:white;")
        self.NavLine.setFrameShadow(QtWidgets.QFrame.Plain)
        self.NavLine.setLineWidth(0)
        self.NavLine.setMidLineWidth(0)
        self.NavLine.setFrameShape(QtWidgets.QFrame.HLine)
        self.NavLine.setObjectName("NavLine")
        self.ProjectNameLabel = QtWidgets.QLabel(self.centralwidget)
        self.ProjectNameLabel.setGeometry(QtCore.QRect(43, 6, 150, 25))
        self.ProjectNameLabel.setStyleSheet("font-family: Segoe Script;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 20px;\n"
"line-height: 25px;\n"
"\n"
"color: #FFFFFF;\n"
"")
        self.ProjectNameLabel.setObjectName("ProjectNameLabel")
        self.IconMain = QtWidgets.QLabel(self.centralwidget)
        self.IconMain.setGeometry(QtCore.QRect(10, 6, 20, 25))
        self.IconMain.setPixmap(QtGui.QPixmap("logos/hanger.png").scaled(20,20))
        self.IconMain.setObjectName("IconMain")
        self.IconMain.setStyleSheet("")

        self.IconMainCut = QtWidgets.QPushButton(self.centralwidget)
        self.IconMainCut.setGeometry(QtCore.QRect(930, 6, 20, 25))
        icon20 = QtGui.QIcon()
        icon20.addPixmap(QtGui.QPixmap("logos/qut.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.IconMainCut.setIcon(icon20)
        #self.IconMainCut.setPixmap(QtGui.QPixmap("logos/qut.png").scaled(20,20))
        self.IconMainCut.setObjectName("IconMain")
        self.IconMainCut.setStyleSheet("")
        #self.IconMainCut.clicked.connect(self.Exit)
        
        
        self.MainTabs = QtWidgets.QTabWidget(self.centralwidget)
        self.MainTabs.setGeometry(QtCore.QRect(0, 40, 960, 500))
        font = QtGui.QFont()
        font.setStyleStrategy(QtGui.QFont.PreferDefault)
        self.MainTabs.setFont(font)
        self.MainTabs.setMouseTracking(False)
        self.MainTabs.setFocusPolicy(QtCore.Qt.NoFocus)
        self.MainTabs.setContextMenuPolicy(QtCore.Qt.NoContextMenu)
        self.MainTabs.setLayoutDirection(QtCore.Qt.LeftToRight)
        self.MainTabs.setAutoFillBackground(False)
        self.MainTabs.setTabPosition(QtWidgets.QTabWidget.East)
        self.MainTabs.setTabShape(QtWidgets.QTabWidget.Rounded)
        self.MainTabs.setIconSize(QtCore.QSize(66, 100))
        self.MainTabs.setElideMode(QtCore.Qt.ElideNone)
        self.MainTabs.setMovable(False)
        self.MainTabs.setTabBarAutoHide(False)
        self.MainTabs.setObjectName("MainTabs")
        
        self.IconMain = QtWidgets.QLabel(self.MainTabs)
        self.IconMain.setGeometry(QtCore.QRect(100, 10, 200, 100))
        #icon15 = QtGui.QIcon()
        self.IconMain.setPixmap(QtGui.QPixmap("logos/hanger.png").scaled(100,100))
        #self.IconMain.setIcon(icon15)
        #self.IconMain.setIconSize(QtCore.QSize(88, 100))
        self.IconMain.setObjectName("IconMain")
        self.IconMain.setStyleSheet("")

        self.LoginLabel = QtWidgets.QLabel(self.MainTabs)
        self.LoginLabel.setGeometry(QtCore.QRect(400, 67,206, 32))
        self.LoginLabel.setStyleSheet("font-family:Segoe Script;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 36px;\n"
"line-height: 90%;\n"
"/* or 32px */\n"
"\n"
"text-align: center;\n"
"text-transform: uppercase;\n"
"\n"
"color: #FFFFFF;")
        self.LoginLabel.setObjectName("LoginLabel")
        self.UserNameLabel = QtWidgets.QLabel(self.MainTabs)
        self.UserNameLabel.setGeometry(QtCore.QRect(250, 142, 117, 16))
        self.UserNameLabel.setStyleSheet("\n"
"font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 18px;\n"
"line-height: 90%;\n"
"/* or 16px */\n"
"\n"
"\n"
"color: #FFFFFF;")
        self.UserNameLabel.setObjectName("UserNameLabel")
        self.UserNameInput = QtWidgets.QLineEdit(self.MainTabs)
        self.UserNameInput.setGeometry(QtCore.QRect(250, 162, 480, 50))
        self.UserNameInput.setPlaceholderText('Please enter your Email id registered')
        self.UserNameInput.setStyleSheet("border: 2px solid #FFFFFF;\n"
"box-sizing: border-box;\n"
"border-radius: 10px;\n"
"font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 18px;\n"
"color:white;")
        self.UserNameInput.setObjectName("UserNameInput")
        self.PasswordNameLabel = QtWidgets.QLabel(self.MainTabs)
        self.PasswordNameLabel.setGeometry(QtCore.QRect(250, 242, 113, 16))
        self.PasswordNameLabel.setStyleSheet("\n"
"font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 18px;\n"
"line-height: 90%;\n"
"/* or 16px */\n"
"\n"
"\n"
"color: #FFFFFF;")
        self.PasswordNameLabel.setObjectName("PasswordNameLabel")
        self.PasswordNameInput = QtWidgets.QLineEdit(self.MainTabs)
        self.PasswordNameInput.setPlaceholderText('Please enter your password')
        self.PasswordNameInput.setGeometry(QtCore.QRect(250, 262, 480, 50))
        self.PasswordNameInput.setStyleSheet("border: 2px solid #FFFFFF;\n"
"box-sizing: border-box;\n"
"border-radius: 10px;\n"
"font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 18px;\n"
"color:white;")
        self.PasswordNameInput.setObjectName("PasswordNameInput")
        self.PasswordNameInput.setEchoMode(QtWidgets.QLineEdit.Password);
        self.LoginButtonSettings = QtWidgets.QPushButton(self.MainTabs)
        self.LoginButtonSettings.setGeometry(QtCore.QRect(280, 342, 400, 50))
        self.LoginButtonSettings.setStyleSheet("\n"
"background: #C4C4C4;\n"
"border-radius: 10px;\n"
"font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 24px;\n"
"line-height: 90%;")
        self.LoginButtonSettings.setObjectName("LoginButtonSettings")
        #print("Login")
        self.LoginButtonSettings.clicked.connect(self.LoginButtonClicked)
        icon17 = QtGui.QIcon()
        icon17.addPixmap(QtGui.QPixmap(":/newPrefix/logos/SettingsTabIcon.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        icon18 = QtGui.QIcon()
        icon18.addPixmap(QtGui.QPixmap(":/newPrefix/logos/StatusTabIcon.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
       
        MainWindow.setCentralWidget(self.centralwidget)

        self.retranslateUi(MainWindow)
        self.MainTabs.setCurrentIndex(0)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)
        
        
    def LoginButtonClicked(self): 
        
        msg = QtWidgets.QMessageBox()
        #print("Login",GlobalVar.username)
        GlobalVar.username =self.UserNameInput.text()
        password =self.PasswordNameInput.text()
        #print("Login",GlobalVar.username)
        if  (Authentication(GlobalVar.username,password)):
            
            self.Window=QtWidgets.QMainWindow()
            self.ui=Ui_MainWindowHome()
            self.ui.setupUi(self.Window)
            self.Window.show()
        else:
            
            msg.setText("Enter Correct Details")
            msg.setWindowTitle("                                ")
            msg.setStyleSheet("background: #C4C4C4;\n"
"font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n")
            msg.exec_()  


    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "MainWindow"))
        self.ProjectNameLabel.setText(_translate("MainWindow", "Dress UP"))
        self.LoginLabel.setText(_translate("MainWindow", "LOGIN"))
        self.UserNameLabel.setText(_translate("MainWindow", "Username"))
        self.PasswordNameLabel.setText(_translate("MainWindow", "Password"))
        self.LoginButtonSettings.setText(_translate("MainWindow", "LOGIN"))

# %%
class Ui_MainWindowSignup(object):
    def setupUi(self, MainWindow1):
        MainWindow1.setObjectName("MainWindow")
        MainWindow1.resize(960, 540)
        MainWindow1.setMinimumSize(QtCore.QSize(960, 540))
        MainWindow1.setMaximumSize(QtCore.QSize(960, 540))
        MainWindow1.setCursor(QtGui.QCursor(QtCore.Qt.BlankCursor))
        MainWindow1.setStyleSheet("background-color: #420516;")
        #MainWindow1.setTabShape(QtWidgets.QTabWidget.Rounded)
        self.centralwidget = QtWidgets.QWidget(MainWindow1)
        self.centralwidget.setCursor(QtGui.QCursor(QtCore.Qt.OpenHandCursor))
        self.centralwidget.setObjectName("centralwidget")
        self.NavLine = QtWidgets.QFrame(self.centralwidget)
        self.NavLine.setGeometry(QtCore.QRect(0, 40, 960, 2))
        self.NavLine.setAutoFillBackground(False)
        self.NavLine.setStyleSheet("color:white;")
        self.NavLine.setFrameShadow(QtWidgets.QFrame.Plain)
        self.NavLine.setLineWidth(0)
        self.NavLine.setMidLineWidth(0)
        self.NavLine.setFrameShape(QtWidgets.QFrame.HLine)
        self.NavLine.setObjectName("NavLine")
        self.ProjectNameLabel = QtWidgets.QLabel(self.centralwidget)
        self.ProjectNameLabel.setGeometry(QtCore.QRect(43, 6, 150, 25))
        self.ProjectNameLabel.setStyleSheet("font-family: Segoe Script;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 20px;\n"
"line-height: 25px;\n"
"\n"
"color: #FFFFFF;\n"
"")
        self.ProjectNameLabel.setObjectName("ProjectNameLabel")
        self.IconMain = QtWidgets.QLabel(self.centralwidget)
        self.IconMain.setGeometry(QtCore.QRect(10, 6, 20, 25))
        self.IconMain.setPixmap(QtGui.QPixmap("logos/hanger.png").scaled(20,20))
        self.IconMain.setObjectName("IconMain")
        self.IconMain.setStyleSheet("")
        
        self.IconMainCut = QtWidgets.QPushButton(self.centralwidget)
        self.IconMainCut.setGeometry(QtCore.QRect(930, 6, 20, 25))
        icon20 = QtGui.QIcon()
        icon20.addPixmap(QtGui.QPixmap("logos/qut.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.IconMainCut.setIcon(icon20)
        #self.IconMainCut.setPixmap(QtGui.QPixmap("logos/qut.png").scaled(20,20))
        self.IconMainCut.setObjectName("IconMain")
        self.IconMainCut.setStyleSheet("")
        #self.IconMainCut.clicked.connect(self.Exit)
        
        
        self.MainTabs = QtWidgets.QTabWidget(self.centralwidget)
        self.MainTabs.setGeometry(QtCore.QRect(0, 40, 960, 500))
        font = QtGui.QFont()
        font.setStyleStrategy(QtGui.QFont.PreferDefault)
        self.MainTabs.setFont(font)
        self.MainTabs.setMouseTracking(False)
        self.MainTabs.setFocusPolicy(QtCore.Qt.NoFocus)
        self.MainTabs.setContextMenuPolicy(QtCore.Qt.NoContextMenu)
        self.MainTabs.setLayoutDirection(QtCore.Qt.LeftToRight)
        self.MainTabs.setAutoFillBackground(False)
        self.MainTabs.setTabPosition(QtWidgets.QTabWidget.East)
        self.MainTabs.setTabShape(QtWidgets.QTabWidget.Rounded)
        self.MainTabs.setIconSize(QtCore.QSize(66, 100))
        self.MainTabs.setElideMode(QtCore.Qt.ElideNone)
        self.MainTabs.setMovable(False)
        self.MainTabs.setTabBarAutoHide(False)
        self.MainTabs.setObjectName("MainTabs")
        
        self.IconMain = QtWidgets.QLabel(self.MainTabs)
        self.IconMain.setGeometry(QtCore.QRect(50, 10, 200, 100))
        #icon15 = QtGui.QIcon()
        self.IconMain.setPixmap(QtGui.QPixmap("logos/hanger.png").scaled(100,100))
        #self.IconMain.setIcon(icon15)
        #self.IconMain.setIconSize(QtCore.QSize(88, 100))
        self.IconMain.setObjectName("IconMain")
        self.IconMain.setStyleSheet("")


        self.emailinput = QtWidgets.QLineEdit(self.MainTabs)
        self.emailinput.setGeometry(QtCore.QRect(410, 90, 400, 50))
        self.emailinput.setStyleSheet("border: 2px solid #FFFFFF;\n"
"box-sizing: border-box;\n"
"border-radius: 10px;\n"
"font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 18px;\n"
"color:white;")
        self.emailinput.setObjectName("emailinput")
        self.emailinput.setValidator(QtGui.QRegExpValidator(QtCore.QRegExp(r"^[a-zA-Z0-9+_.-]+@[a-zA-Z0-9.-]+$")))
        self.emailinput.setPlaceholderText('Please enter your email id')
        
        self.DOB = QtWidgets.QLineEdit(self.MainTabs)
        self.DOB.setGeometry(QtCore.QRect(410, 270, 400, 50))
        self.DOB.setStyleSheet("border: 2px solid #FFFFFF;\n"
"box-sizing: border-box;\n"
"border-radius: 10px;\n"
"font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 18px;\n"
"color:white;")
        self.DOB.setObjectName("DOB")
        self.DOB.setPlaceholderText('dd/mm/yyyy')
        self.DOB.setValidator(QtGui.QRegExpValidator(QtCore.QRegExp(r"^(0?[1-9]|[12][0-9]|3[01])/(0?[1-9]|1[0-2])/\d\d\d\d$")))
        
        self.GenderInput = QtWidgets.QComboBox(self.MainTabs)
        self.GenderInput.setGeometry(QtCore.QRect(410, 210, 400, 50))
        self.GenderInput.setStyleSheet("border: 2px solid #FFFFFF;\n"
"box-sizing: border-box;\n"
"border-radius: 10px;\n"
"font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 18px;\n"
"color:white;")
        self.GenderInput.setObjectName("GenderInput")
        self.GenderInput.addItem("Female")
        self.GenderInput.addItem("Male")
        
        self.PasswordInput = QtWidgets.QLineEdit(self.MainTabs)
        self.PasswordInput.setGeometry(QtCore.QRect(410, 150, 400, 50))
        self.PasswordInput.setStyleSheet("border: 2px solid #FFFFFF;\n"
"box-sizing: border-box;\n"
"border-radius: 10px;\n"
"font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 18px;\n"
"color:white;")
        self.PasswordInput.setObjectName("PasswordInput")
        self.PasswordInput.setValidator(QtGui.QRegExpValidator(QtCore.QRegExp(r"^\d\d\d\d\d\d\d\d$")))
        self.PasswordInput.setPlaceholderText('create your password')
        self.PasswordInput.setEchoMode(QtWidgets.QLineEdit.Password);
        
                
        self.skintonecontent = QtWidgets.QLabel(self.MainTabs)
        self.skintonecontent.setGeometry(QtCore.QRect(180, 320, 900, 30))
        font = QtGui.QFont()
        font.setPointSize(-1)
        self.skintonecontent.setFont(font)
        self.skintonecontent.setStyleSheet("font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 12px;\n"
"line-height: 25px;\n"
"\n"
"color: #FFFFFF;\n"
"")
        self.skintonecontent.setObjectName("skintonecontent")
        self.skintonecontent.setText("Take a look at your arm. If the veins on your wrist are more blue than green, you have cool-toned skin. \n"
        " If they’re more green, your skin is warm-toned. If it’s hard to tell, you likely have a neutral skin tone") 
        self.skintoneinput = QtWidgets.QComboBox(self.MainTabs) 
        self.skintoneinput.setGeometry(QtCore.QRect(410, 360, 400, 50))
        font = QtGui.QFont()
        font.setFamily("Segoe Script")
        font.setPointSize(12)
        font.setBold(True)
        font.setWeight(75)
        self.skintoneinput.setFont(font)
        self.skintoneinput.setStyleSheet("border: 2px solid #FFFFFF;\n"
"box-sizing: border-box;\n"
"border-radius: 10px;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 18px;\n" 
"color:white;")
        #self.skintoneinput.setCurrentText("select SkinTone")
        self.skintoneinput.setObjectName("skintoneinput")
        #self.skintoneinput.addItem("select SkinTone")
        self.skintoneinput.addItem("Warm Tone")
        self.skintoneinput.addItem("Cold Tone")
        self.skintoneinput.addItem("Neutral Tone")
        self.emailalbel = QtWidgets.QLabel(self.MainTabs)
        self.emailalbel.setGeometry(QtCore.QRect(180, 100, 117, 16))
        self.emailalbel.setStyleSheet("\n"
"font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 18px;\n"
"line-height: 90%;\n"
"/* or 16px */\n"
"\n"
"\n"
"color: #FFFFFF;")
        self.emailalbel.setObjectName("emailalbel")
        self.passwrodlabel = QtWidgets.QLabel(self.MainTabs)
        self.passwrodlabel.setGeometry(QtCore.QRect(180, 160, 117, 16))
        self.passwrodlabel.setStyleSheet("\n"
"font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 18px;\n"
"line-height: 90%;\n"
"/* or 16px */\n"
"\n"
"\n"
"color: #FFFFFF;")
        self.passwrodlabel.setObjectName("passwrodlabel")
        
        self.genderlabel = QtWidgets.QLabel(self.MainTabs)
        self.genderlabel.setGeometry(QtCore.QRect(180, 220, 117, 16))
        self.genderlabel.setStyleSheet("\n"
"font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 18px;\n"
"line-height: 90%;\n"
"/* or 16px */\n"
"\n"
"\n"
"color: #FFFFFF;")
        self.genderlabel.setObjectName("genderlabel")
        self.DOBlabel = QtWidgets.QLabel(self.MainTabs)
        self.DOBlabel.setGeometry(QtCore.QRect(180, 290, 117, 16))
        self.DOBlabel.setStyleSheet("\n"
"font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 18px;\n"
"line-height: 90%;\n"
"/* or 16px */\n"
"\n"
"\n"
"color: #FFFFFF;")
        self.DOBlabel.setObjectName("DOBlabel")

        self.skintonelabel = QtWidgets.QLabel(self.MainTabs)
        self.skintonelabel.setGeometry(QtCore.QRect(180, 360, 117, 16))
        self.skintonelabel.setStyleSheet("\n"
"font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 18px;\n"
"line-height: 90%;\n"
"/* or 16px */\n"
"\n"
"\n"
"color: #FFFFFF;")
        self.skintonelabel.setObjectName("skintonelabel")
        self.SignupBtn = QtWidgets.QPushButton(self.MainTabs)
        self.SignupBtn.setGeometry(QtCore.QRect(250, 420, 400, 50))
        self.SignupBtn.setStyleSheet("\n"
"background: #C4C4C4;\n"
"border-radius: 10px;\n"
"font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 24px;\n"
"line-height: 90%;")
        self.SignupBtn.setObjectName("SignupBtn")
        self.SignupLabel = QtWidgets.QLabel(self.MainTabs)
        self.SignupLabel.setGeometry(QtCore.QRect(330, 20, 206, 32))
        self.SignupLabel.setStyleSheet("font-family:Segoe Script;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 36px;\n"
"line-height: 90%;\n"
"/* or 32px */\n"
"\n"
"text-align: center;\n"
"text-transform: uppercase;\n"
"\n"
"color: #FFFFFF;")
        self.SignupLabel.setObjectName("SignupLabel")
        self.SignupBtn.clicked.connect(self.signup)
        icon19 = QtGui.QIcon()
        icon19.addPixmap(QtGui.QPixmap(":/newPrefix/logos/ParkingTabIcon.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
      
        MainWindow1.setCentralWidget(self.centralwidget)

        self.retranslateUi(MainWindow1)
        self.MainTabs.setCurrentIndex(0)
        QtCore.QMetaObject.connectSlotsByName(MainWindow1)
    def signup(self):
        
        #elf.Window.close()
        msg = QtWidgets.QMessageBox()
       # msg.setIcon(QtWidgets.QMessageBox.Warning)
        if self.emailinput.hasAcceptableInput() and self.DOB.hasAcceptableInput() and self.PasswordInput.hasAcceptableInput() :

            Email =self.emailinput.text()
            Password =self.PasswordInput.text()
            DOB =self.DOB.text()
            Gender =self.GenderInput.currentText()
            Skintone=self.skintoneinput.currentText()
            #Insert Data in Database
            if( insertUser( Email ,Password ,DOB ,Gender,Skintone)):
                msg.setText("Success")
                msg.setWindowTitle("                                ")
                msg.setStyleSheet("  border: 2px solid red;\n"
  "border-radius: 5px; ")
                msg.exec_()
                self.Window=QtWidgets.QMainWindow()
                self.ui=Ui_MainWindowLogin()
                self.ui.setupUi(self.Window)
                self.Window.show()
            else:
                msg.setText("Already Registered ")
                msg.exec_()
                
  
        elif  not(self.emailinput.hasAcceptableInput()) :

            
            msg.setText("Enter Correct Email Address")
            msg.setWindowTitle("                                ")
            msg.setStyleSheet("background: #C4C4C4;\n"
"font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n")
                
            msg.exec_() 
        elif  not(self.DOB.hasAcceptableInput())   :

            
            msg.setText("Enter Correct DOB")
            msg.setWindowTitle("                                ")
            msg.setStyleSheet("background: #C4C4C4;\n"
"font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n")
                
            msg.exec_() 
        elif  not(self.PasswordInput.hasAcceptableInput()) :

            
            msg.setText("Enter Strong Password")
            msg.setWindowTitle("                                ")
            msg.setStyleSheet("background: #C4C4C4;\n"
"font-family: Plus Jakarta Sans;\n"
"font-style: normal;\n")
                
            msg.exec_()    
       
    def retranslateUi(self, MainWindow1):
        _translate = QtCore.QCoreApplication.translate
        MainWindow1.setWindowTitle(_translate("MainWindow1", "MainWindow1"))
        self.ProjectNameLabel.setText(_translate("MainWindow1", "Dress UP"))
        self.emailalbel.setText(_translate("MainWindow1", "Email ID"))
        self.passwrodlabel.setText(_translate("MainWindow1", "Password"))
        self.genderlabel.setText(_translate("MainWindow1", "Gender"))
        self.DOBlabel.setText(_translate("MainWindow1", "D.O.B"))
        self.skintonelabel.setText(_translate("MainWindow1", "Skin Tone"))
        self.SignupBtn.setText(_translate("MainWindow1", "SIGNUP"))
        self.SignupLabel.setText(_translate("MainWindow1", "SIGNUP")) 
#import source_rc

# %%
from PIL import Image
 
def most_common_used_color(img):
    # Get width and height of Image
    width, height = img.size
    
    
    newsize = (500, 500)
    img = img.resize(newsize)
    width, height = img.size
    #print(width )
    #print( height)
    a =int(width /2)
    b = int(height /2)
    c = int(a/2)
    d = int(b/2)
    
    left = a -c
    top = b -d
    right = a +c
    bottom = b + d
 
    # Cropped image of above dimension
    # (It will not change original image)
    img = img.crop((left, top, right, bottom))
    
    # Initialize Variable
    r_total = 0
    g_total = 0
    b_total = 0
 
    count = 0
 
    # Iterate through each pixel
    for x in range(0,2*c):
        for y in range(0,2*d):
            # r,g,b value of pixel
            r, g, b = img.getpixel((x, y))
 
            r_total += r
            g_total += g
            b_total += b
            count += 1
     
    return (int(r_total/count), int(g_total/count),int(b_total/count))

# %%
start = False
class Ui_MainWindowHome(object):
    def setupUi(self, MainWindow):

        #print("setupUi")
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(960, 540)
        MainWindow.setMinimumSize(QtCore.QSize(960, 540))
        MainWindow.setMaximumSize(QtCore.QSize(960, 540))
        MainWindow.setCursor(QtGui.QCursor(QtCore.Qt.BlankCursor))
        MainWindow.setStyleSheet("background-color:#420516;")
        MainWindow.setTabShape(QtWidgets.QTabWidget.Rounded)
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setCursor(QtGui.QCursor(QtCore.Qt.OpenHandCursor))
        self.centralwidget.setObjectName("centralwidget")
        
        #NAV LINE
        self.NavLine = QtWidgets.QFrame(self.centralwidget)
        self.NavLine.setGeometry(QtCore.QRect(0, 40, 960, 2))
        self.NavLine.setAutoFillBackground(False)
        self.NavLine.setStyleSheet("color:white;")
        self.NavLine.setFrameShadow(QtWidgets.QFrame.Plain)
        self.NavLine.setLineWidth(0)
        self.NavLine.setMidLineWidth(0)
        self.NavLine.setFrameShape(QtWidgets.QFrame.HLine)
        self.NavLine.setObjectName("NavLine")
        self.ProjectNameLabel = QtWidgets.QLabel(self.centralwidget)
        self.ProjectNameLabel.setGeometry(QtCore.QRect(43, 6, 150, 25))
        self.ProjectNameLabel.setStyleSheet("font-family: Segoe Script;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 20px;\n"
"line-height: 25px;\n"
"\n"
"color: #FFFFFF;\n"
"")
        self.ProjectNameLabel.setObjectName("ProjectNameLabel")
        self.IconMain = QtWidgets.QLabel(self.centralwidget)
        self.IconMain.setGeometry(QtCore.QRect(10, 6, 20, 25))
        self.IconMain.setPixmap(QtGui.QPixmap("logos/hanger.png").scaled(20,20))
        self.IconMain.setObjectName("IconMain")
        self.IconMain.setStyleSheet("")
        
        self.IconMainCut = QtWidgets.QPushButton(self.centralwidget)
        self.IconMainCut.setGeometry(QtCore.QRect(930, 6, 20, 25))
        icon20 = QtGui.QIcon()
        icon20.addPixmap(QtGui.QPixmap("logos/qut.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.IconMainCut.setIcon(icon20)
        #self.IconMainCut.setPixmap(QtGui.QPixmap("logos/qut.png").scaled(20,20))
        self.IconMainCut.setObjectName("IconMain")
        self.IconMainCut.setStyleSheet("")
        #self.IconMainCut.clicked.connect(self.Exit)
        
        
        
        
        #MainTab
        self.MainTabs = QtWidgets.QTabWidget(self.centralwidget)
        self.MainTabs.setGeometry(QtCore.QRect(0, 40, 960, 500))
        font = QtGui.QFont()
        font.setStyleStrategy(QtGui.QFont.PreferDefault)
        self.MainTabs.setFont(font)
        self.MainTabs.setMouseTracking(False)
        self.MainTabs.setFocusPolicy(QtCore.Qt.NoFocus)
        self.MainTabs.setContextMenuPolicy(QtCore.Qt.NoContextMenu)
        self.MainTabs.setLayoutDirection(QtCore.Qt.LeftToRight)
        self.MainTabs.setAutoFillBackground(False)
        self.MainTabs.setTabPosition(QtWidgets.QTabWidget.East)
        self.MainTabs.setTabShape(QtWidgets.QTabWidget.Rounded)
        self.MainTabs.setIconSize(QtCore.QSize(100, 100))
        self.MainTabs.setElideMode(QtCore.Qt.ElideNone)
        self.MainTabs.setMovable(False)
        self.MainTabs.setTabBarAutoHide(False)
        self.MainTabs.setObjectName("MainTabs")
        self.MainTabs.setStyleSheet("QTabBar::tab { background-color:#7D1935; }")
        
        #Closet Tab
        self.ClosetTab = QtWidgets.QWidget()
        font = QtGui.QFont()
        font.setFamily("Arial")
        font.setPointSize(8)
        font.setBold(False)
        font.setWeight(50)
        self.ClosetTab.setFont(font)
        self.ClosetTab.setContextMenuPolicy(QtCore.Qt.NoContextMenu)
        self.ClosetTab.setStyleSheet("background-color:#420516;")
        self.ClosetTab.setObjectName("ClosetTab")
        
        
        #Category Tab
        self.CategoryTab = QtWidgets.QTabWidget(self.ClosetTab)
        self.CategoryTab.setGeometry(QtCore.QRect(0, 0, 855, 500))
        self.CategoryTab.setLayoutDirection(QtCore.Qt.LeftToRight)
        self.CategoryTab.setStyleSheet("")
        self.CategoryTab.setTabPosition(QtWidgets.QTabWidget.West)
        self.CategoryTab.setIconSize(QtCore.QSize(66, 100))
        self.CategoryTab.setObjectName("CategoryTab")
        self.CategoryTab.setStyleSheet("background-color:black;")
        
        #tshirt tab
        self.TshirtTab = QtWidgets.QWidget()
        self.TshirtTab.setStyleSheet("")
        self.TshirtTab.setObjectName("TshirtTab")
        icon = QtGui.QIcon()
        icon.addPixmap(QtGui.QPixmap("logos/t-shirt.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.CategoryTab.addTab(self.TshirtTab, icon, "")
        self.TshirtTabPreviousBT = QtWidgets.QPushButton(self.TshirtTab)
        self.TshirtTabPreviousBT.setGeometry(QtCore.QRect(20, 370, 151, 121))
        icon9 = QtGui.QIcon()
        icon9.addPixmap(QtGui.QPixmap("logos/PreviousBtnFm.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.TshirtTabPreviousBT.setIcon(icon9)
        self.TshirtTabPreviousBT.setIconSize(QtCore.QSize(30, 40))
        self.TshirtTabPreviousBT.setObjectName("PreviousBT")
        self.TshirtTabPreviousBT.setStyleSheet("background-color:black;")
        
        
        
        self.TshirtTabNextBT = QtWidgets.QPushButton(self.TshirtTab)
        self.TshirtTabNextBT.setGeometry(QtCore.QRect(550, 365, 151, 121))
        icon10 = QtGui.QIcon()
        icon10.addPixmap(QtGui.QPixmap("logos/PreviousBtnFm - Copy.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.TshirtTabNextBT.setIcon(icon10)
        self.TshirtTabNextBT.setIconSize(QtCore.QSize(30, 40))
        self.TshirtTabNextBT.setObjectName("NextBT")
        self.TshirtTabNextBT.setStyleSheet("background-color:black;")
        
        ##NEXT PREVIOUS BUTTON OF TSHIRT
        self.TshirtTabNextBT.clicked.connect(self.TshirtTabNextBTclicked)
        self.TshirtTabPreviousBT.clicked.connect(self.TshirtTabPreviousBTclicked)
        
        self.TshirtTabDeleteBT = QtWidgets.QPushButton(self.TshirtTab)
        self.TshirtTabDeleteBT.setGeometry(QtCore.QRect(600, 20, 93, 91))
        self.TshirtTabDeleteBT.setText("")
        icon5 = QtGui.QIcon()
        icon5.addPixmap(QtGui.QPixmap("logos/trash-bin.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.TshirtTabDeleteBT.setIcon(icon5)
        self.TshirtTabDeleteBT.setIconSize(QtCore.QSize(66, 100))
        self.TshirtTabDeleteBT.setObjectName("DeleteBT")
        self.TshirtTabDeleteBT.setStyleSheet("background-color:black;")
        
        
        #DELETE BUTTON
        self.TshirtTabDeleteBT.clicked.connect(self.TshirtTabDeleteDialog)
        
        
        self.TshirtLabel = QtWidgets.QLabel(self.TshirtTab)
        self.TshirtLabel.setGeometry(QtCore.QRect(280, 10, 311, 41))
        font = QtGui.QFont()
        font.setPointSize(-1)
        self.TshirtLabel.setFont(font)
        self.TshirtLabel.setStyleSheet("font-family: Segoe Script;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 30px;\n"
"line-height: 25px;\n"
"\n"
"color: #FFFFFF;\n"
"")
        self.TshirtLabel.setObjectName("TshirtLabel")
        self.TshirtLabel.setText("T-Shirt")
         
        self.TshirtTabviewImage = QtWidgets.QLabel(self.TshirtTab)
        self.TshirtTabviewImage.setGeometry(QtCore.QRect(230, 110, 500, 270))
        self.TshirtTabviewImage.setObjectName("IconMain")
        self.TshirtTabviewImage.setStyleSheet("")
        self.TshirtTabviewImage.setPixmap(QtGui.QPixmap("logos/hanger.png").scaled(200,200))
        
        
        
        
        #Pant Tab
        self.PantTab = QtWidgets.QWidget()
        self.PantTab.setObjectName("PantTab")
        icon1 = QtGui.QIcon()
        icon1.addPixmap(QtGui.QPixmap("logos/trousers.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.CategoryTab.addTab(self.PantTab, icon1, "")
        self.PantTabPreviousBT = QtWidgets.QPushButton(self.PantTab)
        self.PantTabPreviousBT.setGeometry(QtCore.QRect(20, 370, 151, 121))
        icon9 = QtGui.QIcon()
        icon9.addPixmap(QtGui.QPixmap("logos/PreviousBtnFm.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.PantTabPreviousBT.setIcon(icon9)
        self.PantTabPreviousBT.setIconSize(QtCore.QSize(30, 40))
        self.PantTabPreviousBT.setObjectName("PreviousBT")
        self.PantTabPreviousBT.setStyleSheet("background-color:black;")
        
        
        self.PantTabNextBT = QtWidgets.QPushButton(self.PantTab)
        self.PantTabNextBT.setGeometry(QtCore.QRect(550, 365, 151, 121))
        icon10 = QtGui.QIcon()
        icon10.addPixmap(QtGui.QPixmap("logos/PreviousBtnFm - Copy.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.PantTabNextBT.setIcon(icon10)
        self.PantTabNextBT.setIconSize(QtCore.QSize(30, 40))
        self.PantTabNextBT.setObjectName("NextBT")
        self.PantTabNextBT.setStyleSheet("background-color:black;") 
        
        #NEXT PREVIOUS PANT
        self.PantTabNextBT.clicked.connect(self.PantTabNextBTclicked)
        self.PantTabPreviousBT.clicked.connect(self.PantTabPreviousBTclicked)        
                
        self.PantTabDeleteBT = QtWidgets.QPushButton(self.PantTab)
        self.PantTabDeleteBT.setGeometry(QtCore.QRect(600, 20, 93, 91))
        self.PantTabDeleteBT.setText("")
        icon5 = QtGui.QIcon()
        icon5.addPixmap(QtGui.QPixmap("logos/trash-bin.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.PantTabDeleteBT.setIcon(icon5)
        self.PantTabDeleteBT.setIconSize(QtCore.QSize(66, 100))
        self.PantTabDeleteBT.setObjectName("DeleteBT")
        #DELETE DATABASE
        self.PantTabDeleteBT.clicked.connect(self.PantTabDeleteDialog)
        
        self.PantLabel = QtWidgets.QLabel(self.PantTab)
        self.PantLabel.setGeometry(QtCore.QRect(280, 10, 311, 41))
        font = QtGui.QFont()
        font.setPointSize(-1)
        self.PantLabel.setFont(font)
        self.PantLabel.setStyleSheet("font-family: Segoe Script;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 30px;\n"
"line-height: 25px;\n"
"\n"
"color: #FFFFFF;\n"
"")
        self.PantLabel.setObjectName("PantLabel")
        self.PantLabel.setText("Pants")
        
        self.PantTabviewImage = QtWidgets.QLabel(self.PantTab)
        self.PantTabviewImage.setGeometry(QtCore.QRect(230, 110, 500, 270))
        self.PantTabviewImage.setObjectName("IconMain")
        self.PantTabviewImage.setStyleSheet("")
        self.PantTabviewImage.setPixmap(QtGui.QPixmap("logos/hanger.png").scaled(200,200))
        
            
            
        #Boot Tab
        self.BootTab = QtWidgets.QWidget()
        self.BootTab.setObjectName("BootTab")
        icon3 = QtGui.QIcon()
        icon3.addPixmap(QtGui.QPixmap("logos/boots.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.CategoryTab.addTab(self.BootTab, icon3, "")
        self.BootTabPreviousBT = QtWidgets.QPushButton(self.BootTab)
        self.BootTabPreviousBT.setGeometry(QtCore.QRect(20, 370, 151, 121))
        icon9 = QtGui.QIcon()
        icon9.addPixmap(QtGui.QPixmap("logos/PreviousBtnFm.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.BootTabPreviousBT.setIcon(icon9)
        self.BootTabPreviousBT.setIconSize(QtCore.QSize(30, 40))
        self.BootTabPreviousBT.setObjectName("PreviousBT")
        self.BootTabPreviousBT.setStyleSheet("background-color:black;")
        
        
        
        self.BootTabNextBT = QtWidgets.QPushButton(self.BootTab)
        self.BootTabNextBT.setGeometry(QtCore.QRect(550, 365, 151, 121))
        icon10 = QtGui.QIcon()
        icon10.addPixmap(QtGui.QPixmap("logos/PreviousBtnFm - Copy.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.BootTabNextBT.setIcon(icon10)
        self.BootTabNextBT.setIconSize(QtCore.QSize(30, 40))
        self.BootTabNextBT.setObjectName("NextBT")
        self.BootTabNextBT.setStyleSheet("background-color:black;")  
        
        #NEXT PREVIOUS BOOT
        self.BootTabNextBT.clicked.connect(self.BootTabNextBTclicked)
        self.BootTabPreviousBT.clicked.connect(self.BootTabPreviousBTclicked)
        
        
        self.BootTabDeleteBT = QtWidgets.QPushButton(self.BootTab)
        self.BootTabDeleteBT.setGeometry(QtCore.QRect(600, 20, 93, 91))
        self.BootTabDeleteBT.setText("")
        icon5 = QtGui.QIcon()
        icon5.addPixmap(QtGui.QPixmap("logos/trash-bin.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.BootTabDeleteBT.setIcon(icon5)
        self.BootTabDeleteBT.setIconSize(QtCore.QSize(66, 100))
        self.BootTabDeleteBT.setObjectName("DeleteBT")
        #DELTE DATABASE
        self.BootTabDeleteBT.clicked.connect(self.BootTabDeleteDialog)
        
        self.BootLabel = QtWidgets.QLabel(self.BootTab)
        self.BootLabel.setGeometry(QtCore.QRect(280, 10, 311, 41))
        font = QtGui.QFont()
        font.setPointSize(-1)
        self.BootLabel.setFont(font)
        self.BootLabel.setStyleSheet("font-family: Segoe Script;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 30px;\n"
"line-height: 25px;\n"
"\n"
"color: #FFFFFF;\n"
"")
        self.BootLabel.setObjectName("BootLabel")
        self.BootLabel.setText("Boots")          
        
        self.BootTabviewImage = QtWidgets.QLabel(self.BootTab)
        self.BootTabviewImage.setGeometry(QtCore.QRect(230, 110, 500, 270))
        self.BootTabviewImage.setObjectName("IconMain")
        self.BootTabviewImage.setStyleSheet("")
        self.BootTabviewImage.setPixmap(QtGui.QPixmap("logos/hanger.png").scaled(200,200))
        
        
        icon4 = QtGui.QIcon()
        icon4.addPixmap(QtGui.QPixmap("logos/fashion.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.MainTabs.addTab(self.ClosetTab, icon4, "")
       
       
        #Manage Tab
        self.ManageTab = QtWidgets.QWidget()
        self.ManageTab.setObjectName("ManageTab")
        self.ManageTab.setStyleSheet("background-color:black;")
        
        self.ManageTabDeleteBT = QtWidgets.QPushButton(self.ManageTab)
        self.ManageTabDeleteBT.setGeometry(QtCore.QRect(740, 20, 93, 91))
        self.ManageTabDeleteBT.setText("")
        icon5 = QtGui.QIcon()
        icon5.addPixmap(QtGui.QPixmap("logos/trash-bin.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.ManageTabDeleteBT.setIcon(icon5)
        self.ManageTabDeleteBT.setIconSize(QtCore.QSize(66, 100))
        self.ManageTabDeleteBT.setObjectName("DeleteBT")
        self.ManageTabDeleteBT.setStyleSheet("background-color:black;")
        #IMPORT IMAGE DELETE FILE LOCATION NONE
        self.ManageTabDeleteBT.clicked.connect(self.deleteload)
        
        self.AddBT = QtWidgets.QPushButton(self.ManageTab)
        self.AddBT.setGeometry(QtCore.QRect(20, 10, 241, 101))
        icon6 = QtGui.QIcon()
        icon6.addPixmap(QtGui.QPixmap("logos/add12.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.AddBT.setIcon(icon6)
        self.AddBT.setIconSize(QtCore.QSize(66, 100))
        self.AddBT.setObjectName("AddBT")
        self.AddBT.setStyleSheet("background-color:black;")
        #ADD -IMAGE LOAD SHOW UI
        self.AddBT.clicked.connect(self.openDialog)
        
        self.ManageTabviewImage = QtWidgets.QLabel(self.ManageTab)
        self.ManageTabviewImage.setGeometry(QtCore.QRect(350, 150, 300, 300))
        self.ManageTabviewImage.setObjectName("IconMain")
        self.ManageTabviewImage.setStyleSheet("")
        self.ManageTabviewImage.setPixmap(QtGui.QPixmap("logos/hanger.png").scaled(200,200))
        
        
        self.MSelectcomboBox = QtWidgets.QComboBox(self.ManageTab)
        self.MSelectcomboBox.setGeometry(QtCore.QRect(350, 60, 300, 40))
        font = QtGui.QFont()
        font.setFamily("Segoe Script")
        font.setPointSize(12)
        font.setBold(True)
        font.setWeight(75)
        
        self.MSelectcomboBox.setFont(font)
        self.MSelectcomboBox.setStyleSheet("color:white;\n"
        "background-color:#420516;\n")
        self.MSelectcomboBox.addItem("None")
        #self.SelectcomboBox.addItem("select Occassion")
        self.MSelectcomboBox.addItem("Upper Wear")
        self.MSelectcomboBox.addItem("Lower Wear")
        self.MSelectcomboBox.addItem("FootWear")       
        
        
        # MODEL CALL IMAGE CLASSIFICATION DB STORE
        self.ManageTabGenerateBT = QtWidgets.QPushButton(self.ManageTab)
        self.ManageTabGenerateBT.setGeometry(QtCore.QRect(700, 365, 141, 120))
        icon8 = QtGui.QIcon()
        icon8.addPixmap(QtGui.QPixmap("logos/play-button.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.ManageTabGenerateBT.setIcon(icon8)
        self.ManageTabGenerateBT.setIconSize(QtCore.QSize(66, 100))
        self.ManageTabGenerateBT.setObjectName("GenerateBT")
        self.ManageTabGenerateBT.setStyleSheet("background-color:black;")
        self.ManageTabGenerateBT.clicked.connect(self.savetoDatabase)
        
        self.ADDLabel = QtWidgets.QLabel(self.ManageTab)
        self.ADDLabel.setGeometry(QtCore.QRect(340, 10, 311, 41))
        font = QtGui.QFont()
        font.setPointSize(-1)
        self.ADDLabel.setFont(font)
        self.ADDLabel.setStyleSheet("font-family: Segoe Script;\n"
"font-style: normal;\n"
"font-weight: 500;\n"
"font-size: 30px;\n"
"line-height: 25px;\n"
"\n"
"color: #FFFFFF;\n"
"")
        self.ADDLabel.setObjectName("ADDLabel")
        icon7 = QtGui.QIcon()
        icon7.addPixmap(QtGui.QPixmap("logos/setting1.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.MainTabs.addTab(self.ManageTab, icon7, "")
        
        
        #Recommend Tab
        self.RecommendTab = QtWidgets.QWidget()
        self.RecommendTab.setObjectName("RecommendTab")
        self.RecommendTab.setStyleSheet("background-color:black;")
        
        
        self.RecommendTabGenerateBT = QtWidgets.QPushButton(self.RecommendTab)
        self.RecommendTabGenerateBT.setGeometry(QtCore.QRect(700, 0, 141, 120))
        icon8 = QtGui.QIcon()
        icon8.addPixmap(QtGui.QPixmap("logos/play-button.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.RecommendTabGenerateBT.setIcon(icon8)
        self.RecommendTabGenerateBT.setIconSize(QtCore.QSize(66, 100))
        self.RecommendTabGenerateBT.setObjectName("GenerateBT")
        self.RecommendTabGenerateBT.setStyleSheet("background-color:black;")
        #OCCASION SELECT - PASS FUNCTION USE 3-IMAGE UPPER LOWER FOOR 1-1 AATI JAGE
        self.RecommendTabGenerateBT.clicked.connect(self.RecommendOccasion)
        
        
        
        self.RecommendTabPreviousBT = QtWidgets.QPushButton(self.RecommendTab)
        self.RecommendTabPreviousBT.setGeometry(QtCore.QRect(10, 370, 151, 121))
        icon9 = QtGui.QIcon()
        icon9.addPixmap(QtGui.QPixmap("logos/PreviousBtnFm.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.RecommendTabPreviousBT.setIcon(icon9)
        self.RecommendTabPreviousBT.setIconSize(QtCore.QSize(30, 40))
        self.RecommendTabPreviousBT.setObjectName("PreviousBT")
        self.RecommendTabPreviousBT.setStyleSheet("background-color:black;")
        #PREVIOUS RECCOMEND IMAGES
        self.RecommendTabPreviousBT.clicked.connect(self.RecommendTabPreviousBTOccasion)
        
        
        self.RecommendTabNextBT = QtWidgets.QPushButton(self.RecommendTab)
        self.RecommendTabNextBT.setGeometry(QtCore.QRect(690, 365, 151, 121))
        icon10 = QtGui.QIcon()
        icon10.addPixmap(QtGui.QPixmap("logos/PreviousBtnFm - Copy.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.RecommendTabNextBT.setIcon(icon10)
        self.RecommendTabNextBT.setIconSize(QtCore.QSize(30, 40))
        self.RecommendTabNextBT.setObjectName("NextBT")
        self.RecommendTabNextBT.setStyleSheet("background-color:black;")
        #NEXTRECCOMEND IMAGES
        self.RecommendTabNextBT.clicked.connect(self.RecommendTabNextBTOccasion)
        
        self.RecommendTabviewImage = QtWidgets.QLabel(self.RecommendTab)
        self.RecommendTabviewImage.setGeometry(QtCore.QRect(30, 110, 500, 270))###x,y,length,width
        self.RecommendTabviewImage.setObjectName("IconMain")
        self.RecommendTabviewImage.setStyleSheet("")
        self.RecommendTabviewImage.setPixmap(QtGui.QPixmap("logos/hanger.png").scaled(200,200))
        
        
        self.RecommendTabviewImage1 = QtWidgets.QLabel(self.RecommendTab)
        self.RecommendTabviewImage1.setGeometry(QtCore.QRect(330, 110, 500, 270))
        self.RecommendTabviewImage1.setObjectName("IconMain")
        self.RecommendTabviewImage1.setStyleSheet("")
        self.RecommendTabviewImage1.setPixmap(QtGui.QPixmap("logos/hanger.png").scaled(200,200))
        
        self.RecommendTabviewImage2 = QtWidgets.QLabel(self.RecommendTab)
        self.RecommendTabviewImage2.setGeometry(QtCore.QRect(630, 110, 500, 270))
        self.RecommendTabviewImage2.setObjectName("IconMain")
        self.RecommendTabviewImage2.setStyleSheet("")
        self.RecommendTabviewImage2.setPixmap(QtGui.QPixmap("logos/hanger.png").scaled(200,200))
        
        
        self.SelectcomboBox = QtWidgets.QComboBox(self.RecommendTab)
        self.SelectcomboBox.setGeometry(QtCore.QRect(40, 30, 200, 30))
        font = QtGui.QFont()
        font.setFamily("Segoe Script")
        font.setPointSize(12)
        font.setBold(True)
        font.setWeight(75)
        
        
        
        self.SelectcomboBox.setFont(font)
        self.SelectcomboBox.setStyleSheet("color:white;\n"
        "background-color:#420516;\n")
        self.SelectcomboBox.setCurrentText("")
        #self.SelectcomboBox.addItem("select Occassion")
        self.SelectcomboBox.addItem("Party")
        self.SelectcomboBox.addItem("Casual")
        self.SelectcomboBox.addItem("Winter")
        self.SelectcomboBox.addItem("Formal")
        #self.SelectcomboBox.move(50, 250)

        icon11 = QtGui.QIcon()
        icon11.addPixmap(QtGui.QPixmap("logos/gjhgjh.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        self.MainTabs.addTab(self.RecommendTab, icon11, "")

        MainWindow.setCentralWidget(self.centralwidget)

        self.retranslateUi(MainWindow)
        self.MainTabs.setCurrentIndex(0)
        self.CategoryTab.setCurrentIndex(3)
        #print("semifinal",GlobalVar.username)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)

 

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "MainWindow"))
        self.ProjectNameLabel.setText(_translate("MainWindow", "Dress UP"))
        #self.AddBT.setText(_translate("MainWindow", "PushButton"))
        self.ADDLabel.setText(_translate("MainWindow", "Add to Closet"))
        #self.GenerateBT.setText(_translate("MainWindow", "PushButton"))
        #self.PreviousBT.setText(_translate("MainWindow", "PushButton"))
        #self.NextBT.setText(_translate("MainWindow", "PushButton"))
    def openDialog(self):        
        _translate = QtCore.QCoreApplication.translate
        GlobalVar.directory = QFileDialog.getOpenFileName(None, "Select file", "H:/")
        #print(GlobalVar.directory[0])
        
        img = Image.open(GlobalVar.directory[0])
 
        # Convert Image into RGB
        img = img.convert('RGB')
 
        # call function
        self.common_color = most_common_used_color(img)
 
        print(self.common_color)
        #######Convert different image format to jpg
        self.ManageTabviewImage.setPixmap(QtGui.QPixmap(GlobalVar.directory[0]).scaled(200,200))
        
    def savetoDatabase(self):
        wear=self.MSelectcomboBox.currentText()
        
            
        sub, info, res_place_holder = single_classification(GlobalVar.directory[0],GlobalVar.sub_model,GlobalVar.top_model,GlobalVar.bottom_model,GlobalVar.foot_model)
        #print(res_place_holder[2])
        print(self.common_color)
        hsv =colors.rgb_to_hsv(self.common_color)
        print(hsv)
        h = hsv[0]
        s = hsv[1]
        v = hsv [2]
        
        if wear  == "None":
            insertStorage(res_place_holder[0],res_place_holder[1],res_place_holder[2],res_place_holder[3],res_place_holder[4],res_place_holder[5],GlobalVar.username,h,s,v)
        else :
            if wear == "Upper Wear":
                wear = 'top'
            elif wear == "Lower Wear":
                wear =  'bottom'
            elif wear == "FootWear":
                wear = 'foot'
            insertStorage(wear,res_place_holder[1],res_place_holder[2],res_place_holder[3],res_place_holder[4],res_place_holder[5],GlobalVar.username,h,s,v)
       
        self.ManageTabviewImage.setPixmap(QtGui.QPixmap("logos/hanger.png").scaled(200,200))
    

            
            
            
            
    def deleteload(self):
        GlobalVar.directory = None
        self.ManageTabviewImage.setPixmap(QtGui.QPixmap("logos/hanger.png").scaled(200,200))
        #mageloadlightdark
    def TshirtTabNextBTclicked(self):
        a =showimagenext('top',GlobalVar.username)#return file location to show
        im = Image.open(a)
        width, height = im.size
        newsize = (250, 250)
        im = im.resize(newsize)
        im = im.save(a)
        self.TshirtTabviewImage.setPixmap(QtGui.QPixmap(a).scaled(250,250))
    def TshirtTabPreviousBTclicked(self):
        a =showimageprevious('top',GlobalVar.username)#return file location to show
        im = Image.open(a)
        width, height = im.size
        newsize = (250, 250)
        im = im.resize(newsize)
        im = im.save(a)
        self.TshirtTabviewImage.setPixmap(QtGui.QPixmap(a).scaled(250,250))
    def PantTabNextBTclicked(self):
        a =showimagenext('bottom',GlobalVar.username)#return file location to show
        im = Image.open(a)
        width, height = im.size
        newsize = (250, 250)
        im = im.resize(newsize)
        im = im.save(a)
        self.PantTabviewImage.setPixmap(QtGui.QPixmap(a).scaled(250,250))
    def PantTabPreviousBTclicked(self):
        a =showimageprevious('bottom',GlobalVar.username)#return file location to show
        im = Image.open(a)
        width, height = im.size
        newsize = (250, 250)
        im = im.resize(newsize)
        im = im.save(a)
        self.PantTabviewImage.setPixmap(QtGui.QPixmap(a).scaled(250,250))        
    def BootTabNextBTclicked(self):
        a =showimagenext('foot',GlobalVar.username)#return file location to show
        im = Image.open(a)
        width, height = im.size
        newsize = (250, 250)
        im = im.resize(newsize)
        im = im.save(a)
        self.BootTabviewImage.setPixmap(QtGui.QPixmap(a).scaled(250,250))
    def BootTabPreviousBTclicked(self):
        a =showimageprevious('foot',GlobalVar.username)#return file location to show
        im = Image.open(a)
        width, height = im.size
        newsize = (250, 250)
        im = im.resize(newsize)
        im = im.save(a)
        self.BootTabviewImage.setPixmap(QtGui.QPixmap(a).scaled(250,250))

    def BootTabDeleteDialog(self):
        deleteCloset('foot',GlobalVar.username)
        self.BootTabviewImage.setPixmap(QtGui.QPixmap("logos/hanger.png").scaled(200,200))

    def PantTabDeleteDialog(self):
        deleteCloset('bottom',GlobalVar.username)
        self.PantTabviewImage.setPixmap(QtGui.QPixmap("logos/hanger.png").scaled(200,200))
    def TshirtTabDeleteDialog(self):
        deleteCloset('top',GlobalVar.username)
        self.TshirtTabviewImage.setPixmap(QtGui.QPixmap("logos/hanger.png").scaled(200,200))
    def RecommendOccasion(self):
        print("Recoomend")
        a=self.SelectcomboBox .currentText()
        #first check if database have pictures in it or not
        content =checkDatabase(GlobalVar.username)
        if(content):
            msg = QtWidgets.QMessageBox()
            msg.setText(content)
            msg.exec_()
                 
        else :
            #dataset contain data now recommend
            print("start")
            ViewFuzzy(GlobalVar.username)
            global start
            start = True
    def RecommendTabPreviousBTOccasion(self):
        print("Pre")
        global start
        if start :
            print("enter")
            if (Previous(GlobalVar.username)):
                print("ffg")
                location1 = "rectop.jpg"
                location2 = "recbot.jpg"
                location3 = "recfot.jpg"
                im = Image.open(location1)
                width, height = im.size
                newsize = (250, 250)
                im = im.resize(newsize)
                im = im.save(location1)
                self.RecommendTabviewImage.setPixmap(QtGui.QPixmap(location1).scaled(250,250))

                im = Image.open(location2)
                width, height = im.size
                newsize = (250, 250)
                im = im.resize(newsize)
                im = im.save(location2)
                self.RecommendTabviewImage1.setPixmap(QtGui.QPixmap(location2).scaled(250,250))

                im = Image.open(location3)
                width, height = im.size
                newsize = (250, 250)
                im = im.resize(newsize)
                im = im.save(location3)
                self.RecommendTabviewImage2.setPixmap(QtGui.QPixmap(location3).scaled(250,250))
            
    def RecommendTabNextBTOccasion(self):
        print("next")
        global start
        if start :
            print("enter nr")
            if (Next(GlobalVar.username)):
                print("fd")
                location1 = "rectop.jpg"
                location2 = "recbot.jpg"
                location3 = "recfot.jpg"
                im = Image.open(location1)
                width, height = im.size
                newsize = (250, 250)
                im = im.resize(newsize)
                im = im.save(location1)
                self.RecommendTabviewImage.setPixmap(QtGui.QPixmap(location1).scaled(250,250))

                im = Image.open(location2)
                width, height = im.size
                newsize = (250, 250)
                im = im.resize(newsize)
                im = im.save(location2)
                self.RecommendTabviewImage1.setPixmap(QtGui.QPixmap(location2).scaled(250,250))

                im = Image.open(location3)
                width, height = im.size
                newsize = (250, 250)
                im = im.resize(newsize)
                im = im.save(location3)
                self.RecommendTabviewImage2.setPixmap(QtGui.QPixmap(location3).scaled(250,250))

# %%
if __name__ == "__main__":
    ui = Ui_MainWindow()
    ui.setupUi(MainWindow)
    MainWindow.show()
    sys.exit(app.exec_())
# Out:
# (182, 193, 216)
# [] [] []
# loadModel
# (182, 193, 216)
# [6.12745098e-01 1.57407407e-01 2.16000000e+02]
# (182, 193, 216)
# [6.12745098e-01 1.57407407e-01 2.16000000e+02]
